# %%
import pandas as pd  # keywords are highlighted in green, other strings in red, etc.
import numpy as np

# %%
#1. Show the DataFrame's shape.
mca = pd.read_csv('marketing_customer_analysis.csv')

display(mca.head())
display(mca.tail())
mca.shape
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
#2. Standardize header names.
cols = []
for i in range(len(mca.columns)):
    cols.append(mca.columns[i].lower())
mca.columns = cols

mca.head()
# Out:
#    unnamed: 0 customer       state  customer lifetime value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective to date employmentstatus gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    number of open complaints number of policies     policy type        policy  \
# ...

# %%
# 3.Which columns are numerical?
num_col = mca._get_numeric_data()
display(num_col)
# Out:
#        unnamed: 0  customer lifetime value  income  monthly premium auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# ...

# %%
#4. Which columns are categorical?
cat_col = mca.select_dtypes(include=['object']).columns
display(cat_col)
# Out:
# Index(['customer', 'state', 'response', 'coverage', 'education',
#        'effective to date', 'employmentstatus', 'gender', 'location code',
#        'marital status', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'vehicle class', 'vehicle size', 'vehicle type'],
#       dtype='object')

# %%
#5. Check and deal with NaN values.
show_nan = mca[mca.isna().any(axis=1)] #using isna() (or isnull()) to select all rows with NaN under an entire DataFrame
mca_value = mca.isnull().values.any() #check for NaN values is True
mca_sum = mca.isnull().sum().sum() #check for NaN sum total is 9254
display(show_nan)
display(mca_value)
display(mca_sum)

#I have a feeling this code is not super duper elegant
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 4               4  QA50777      Oregon              9025.067525       No
# 5               5  HO81102         NaN              4745.181764      NaN
# 6               6  IW72280  California              5035.035257       No
# ...           ...      ...         ...                      ...      ...
# 10900       10900  VN73653      Oregon              6423.739052       No
# 10901       10901  RY92254  Washington              4547.892543       No
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage             education effective to date employmentstatus  \
# ...

# %%
print(mca['vehicle type']) #this is the column with the NaN values
# Out:
# 0        NaN
# 1        NaN
# 2          A
# 3          A
# 4        NaN
#         ...
# 10905      A
# 10906      A
# 10907    NaN
# 10908      A
# 10909    NaN
# Name: vehicle type, Length: 10910, dtype: object

# %%
#drop all rows that have NaN/None values

drop_NaN = mca.dropna() 
display(drop_NaN)

# Reset index after drop
#df2=df.dropna().reset_index(drop=True)

# Drop row that has all NaN values
#df2=df.dropna(how='all')

# Drop rows that has NaN values on selected columns
#df2=df.dropna(subset=['Courses','Fee'])

# With threshold, 
# Keep only the rows with at least 2 non-NA values.
#df2=df.dropna(thresh=2)

# Drop Rows with NaN Values inplace
#df.dropna(inplace=True)
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 10             10  HG93801     Arizona              5154.764074       No
# 13             13  KR82385  California              5454.587929       No
# 16             16  FH51383  California              5326.677654       No
# ...           ...      ...         ...                      ...      ...
# 10902       10902  PP30874  California              3579.023825       No
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective to date employmentstatus  \
# ...

# %%
#no more NaN values in vehicle type column

# %%
# 6. Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the
#information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only 
#January and February.
import pandas as pd
import numpy as np
import datetime
import calendar
import time
from datetime import date

# %%
#mca['month'] = pd.to_datetime(mca['effective to date']).dt.month
#df = df[ (df['month']==1) | (df['month']==2) | (df['month']==3) ]
#df['month']

mca['month'] = pd.DatetimeIndex(mca['effective to date']).month #create a new column with year of date field 'birth_date'
mca.head()
#used mca as data frame again. does that make sense? it's got the NaN values again in vehicle type
# Out:
#    unnamed: 0 customer       state  customer lifetime value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective to date employmentstatus gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    number of policies     policy type        policy  renew offer type  \
# ...

# %%
#Already the information of the first quarter is shown (1 = January, 2 = February), so no need to filter out. March is not available

# %%
#drop_NaN['months'] = pd.DatetimeIndex(drop_NaN['effective to date']).month #only those with no NaN values
#drop_NaN.head() 
#mca['month'] = pd.DatetimeIndex(mca['effective to date']).month         #Original DataFrame with NaN
#mca.head()

# %%
#DAY 3

# %%
#Get the data
#Use the same jupyter file from the last lab, Customer Analysis Round 3
#EDA (Exploratory Data Analysis) - Complete the following tasks to explore the data:
#1 Show DataFrame info.
#2 Describe DataFrame.
#3 Show a plot of the total number of responses.
#4 Show a plot of the response rate by the sales channel.
#5 Show a plot of the response rate by the total claim amount.
#6 Show a plot of the response rate by income.

# %%
#1 
mca.shape
# Out:
# (10910, 27)

# %%
mca.describe()
# Out:
#          unnamed: 0  customer lifetime value        income  \
# count  10910.000000             10910.000000  10910.000000
# mean    5454.500000              8018.241094  37536.284785
# std     3149.590053              6885.081434  30359.195670
# min        0.000000              1898.007675      0.000000
# 25%     2727.250000              4014.453113      0.000000
# 50%     5454.500000              5771.147235  33813.500000
# 75%     8181.750000              8992.779137  62250.750000
# max    10909.000000             83325.381190  99981.000000
#
#        monthly premium auto  months since last claim  \
# count          10910.000000             10277.000000
# mean              93.196059                15.149071
# std               34.442532                10.080349
# min               61.000000                 0.000000
# 25%               68.000000                 6.000000
# 50%               83.000000                14.000000
# 75%              109.000000                23.000000
# ...

# %%
#2
mca.describe().T
# Out:
#                                  count          mean           std  \
# unnamed: 0                     10910.0   5454.500000   3149.590053
# customer lifetime value        10910.0   8018.241094   6885.081434
# income                         10910.0  37536.284785  30359.195670
# monthly premium auto           10910.0     93.196059     34.442532
# months since last claim        10277.0     15.149071     10.080349
# months since policy inception  10910.0     48.091934     27.940675
# number of open complaints      10277.0      0.384256      0.912457
# number of policies             10910.0      2.979193      2.399359
# total claim amount             10910.0    434.888330    292.180556
# month                          10910.0      1.466728      0.498915
#
#                                        min          25%           50%  \
# unnamed: 0                        0.000000  2727.250000   5454.500000
# customer lifetime value        1898.007675  4014.453113   5771.147235
# ...

# %%
#3 Show a plot of the total number of responses.
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#uni_x = mca['response'].unique()
#count_y = mca['response'].value_counts()

#display(uni_x)
#display(count_y)

mca['response'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
mca['response'].value_counts()
# Out:
# No     8813
# Yes    1466
# Name: response, dtype: int64

# %%
mca.dtypes #just checking data types
# Out:
# unnamed: 0                         int64
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# ...

# %%
#3  Show a plot of the total number of responses. 
sns.displot(mca['response'], bins=60)
plt.show()

# %%
#4 Show a plot of the response rate by the sales channel. 2 OBJECTS --> crosstab
cross_results=pd.crosstab(index=mca['response'],columns=mca['sales channel'])
print(cross_results)
# Out:
# sales channel  Agent  Branch  Call Center   Web
# response
# No              3148    2539         1792  1334
# Yes              742     326          221   177

# %%
cross_results.plot.bar()
# Out:
# <AxesSubplot:xlabel='response'>

# %%
#5 Show a plot of the response rate by the total claim amount. 1 OBJECT, 1 INT/FLOAT --> scatterplot
sns.scatterplot(x=mca['response'], y=mca['total claim amount'])
plt.show()

# %%
#6 Show a plot of the response rate by income. 1 OBJECT, 1 INT7/FLOAT --> scatterplot
sns.scatterplot(x=mca['response'], y=mca['income'])
plt.show()

# %% [markdown]
# #Day 4

# %%
#Get the data
#Use the jupyter file from the last lab (Customer Analysis Round 3)

#Complete the following task

#1 Check the data types of the columns. Get the numeric data into dataframe called numerical and categorical columns in a 
#dataframe called categoricals. (You can use np.number and np.object to select the numerical data types and categorical data 
#types respectively)

#2 Now we will try to check the normality of the numerical variables visually


#3 Use seaborn library to construct distribution plots for the numerical variables

#4 Use Matplotlib to construct histograms

#5 Do the distributions for different numerical variables look like a normal distribution

#6 For the numerical variables, check the multicollinearity between the features. Please note that we will use the column 
#total_claim_amount later as the target variable.

#7 Drop one of the two features that show a high correlation between them (greater than 0.9). Write code for both the correlation
#matrix and for seaborn heatmap. If there is no pair of features that have a high correlation, then do not drop any features

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
#1
mca.dtypes
# Out:
# unnamed: 0                         int64
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# ...

# %%
#1 

numericals = mca._get_numeric_data()
del numericals['unnamed: 0'] #removed the column created through a copy
#display(num_col)
numericals.head()
# Out:
#    customer lifetime value  income  monthly premium auto  \
# 0              4809.216960   48029                    61
# 1              2228.525238       0                    64
# 2             14947.917300   22139                   100
# 3             22332.439460   49078                    97
# 4              9025.067525   23675                   117
#
#    months since last claim  months since policy inception  \
# 0                      7.0                             52
# 1                      3.0                             26
# 2                     34.0                             31
# 3                     10.0                              3
# 4                      NaN                             31
#
#    number of open complaints  number of policies  total claim amount  month
# 0                        0.0                   9          292.800000      2
# 1                        0.0                   1          744.924331      1
# ...

# %%
categoricals = mca.select_dtypes(include=['object']).columns
display(categoricals) #Index...not data frame..mmmhhhh
# Out:
# Index(['customer', 'state', 'response', 'coverage', 'education',
#        'effective to date', 'employmentstatus', 'gender', 'location code',
#        'marital status', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'vehicle class', 'vehicle size', 'vehicle type'],
#       dtype='object')

# %%
#2 Now we will try to check the normality of the numerical variables visually
correlations_matrix = numericals.corr()
sns.heatmap(correlations_matrix, annot=True, linewidths=1)
plt.show()
#Pearson's correlation is a measure of the linear relationship (normality) between two continuous random variables
#the heatmap uses pearsons correlation, therefore this should suffice as a normality check for all the numerical variables
#I am not entirely sure how this is different from #3.

# %%
#3 Use seaborn library to construct distribution plots for the numerical variables
for i in range(9):
    sns.displot(numericals.iloc[:,i]) #all hail displot
    plt.show() #distribution of all numerical columns in the dataframe if I'm not mistaken

# %%
#heavily, positively skewered for most of the numerical variables
#except MAYBE 'months since policy' abd 'month'...can use DATA TRANSFORMATION

# %%
#4 Use Matplotlib to construct histograms
plt.hist(numericals, bins = 2)
plt.show()
#the larger the number of the bin, the smaller the histogram

# %%
#or like this
plt.hist(numericals, 2)

plt.show()

# %%
#5 Do the distributions for different numerical variables look like a normal distribution
for i in range(8):
    sns.displot(numericals.iloc[:,i]) #all hail displot
    plt.show() #distribution of all numerical columns in the dataframe if I'm not mistaken
    
    #No, they do not look like a normal distribution. They look positvely skewed.

# %%
#6 For the numerical variables, check the multicollinearity between the features. Please note that we 
#will use the column total_claim_amount later as the target variable.
correlations_matrix = numericals.corr()
sns.heatmap(correlations_matrix, annot=True, linewidths=1)
plt.show()
#Multicollinearity is the occurrence of high intercorrelations among two or more independent variables in a 
#multiple regression model.
#strongest intercorrelation is among 'total claim amount' and 'monthly premium auto'

# %%
#7 Drop one of the two features that show a high correlation between them (greater than 0.9). 
#Write code for both the correlation matrix and for seaborn heatmap. 
#If there is no pair of features that have a high correlation, then do not drop any features.

correlations_matrix = numericals.corr()
display(correlations_matrix)

# the code for the heatmap is in the cell above
# Out:
#                                customer lifetime value    income  \
# customer lifetime value                       1.000000  0.028306
# income                                        0.028306  1.000000
# monthly premium auto                          0.403069 -0.009788
# months since last claim                       0.016052 -0.023814
# months since policy inception                 0.016960 -0.005903
# number of open complaints                    -0.032243  0.007163
# number of policies                            0.016024 -0.009960
# total claim amount                            0.232626 -0.354141
# month                                        -0.009234 -0.000443
#
#                                monthly premium auto  months since last claim  \
# customer lifetime value                    0.403069                 0.016052
# income                                    -0.009788                -0.023814
# monthly premium auto                       1.000000                 0.008744
# ...

# %%
#DAY 4 LAB 2

# %%
#Processing Data (Further processing...)

#1 X-y split.
#2 Normalize (numerical).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

#importing everything, just in case

# %%
#1 X-y split.
numericals.head()
#mca.head()
# Out:
#    customer lifetime value  income  monthly premium auto  \
# 0              4809.216960   48029                    61
# 1              2228.525238       0                    64
# 2             14947.917300   22139                   100
# 3             22332.439460   49078                    97
# 4              9025.067525   23675                   117
#
#    months since last claim  months since policy inception  \
# 0                      7.0                             52
# 1                      3.0                             26
# 2                     34.0                             31
# 3                     10.0                              3
# 4                      NaN                             31
#
#    number of open complaints  number of policies  total claim amount  month
# 0                        0.0                   9          292.800000      2
# 1                        0.0                   1          744.924331      1
# ...

# %%
#train, test = train_test_split(mca, test_size=0.2)

train, test = train_test_split(numericals, test_size=0.2) #--> 20% test, 80% train

# %%
display(len(test)) #--> to check if the split worked
display(test)
# Out:
# 2182
#        customer lifetime value  income  monthly premium auto  \
# 6683               3410.199334   59662                    85
# 10541              8114.409136   30595                    69
# 9873               2439.930981   50876                    61
# 1558               7739.550403   64859                    96
# 10259              4974.873300   48139                    63
# ...                        ...     ...                   ...
# 285                4334.064096   23904                   123
# 2273               8708.279280   30090                    73
# 7605               3472.369996       0                   102
# 1339               8193.555045   54950                   103
# 4682               2404.380963   62488                    62
#
#        months since last claim  months since policy inception  \
# 6683                       6.0                             76
# 10541                     22.0                             36
# ...

# %%
display(len(train)) #--> to check if the split worked
display(train)
# Out:
# 8728
#       customer lifetime value  income  monthly premium auto  \
# 353               3776.665506   68727                    94
# 8459              2809.766683   74713                    70
# 8895              4740.202507       0                    72
# 8178              2566.867823   25049                    67
# 260               9587.586583   84539                   119
# ...                       ...     ...                   ...
# 6538              8388.717011   87123                    69
# 234              15032.900300   17150                    65
# 8417              2572.452634   72685                    68
# 9241              3940.123576   92539                   100
# 6121             22448.686170       0                    78
#
#       months since last claim  months since policy inception  \
# 353                      19.0                             76
# 8459                     20.0                             67
# ...

# %%
##2 Normalize (numerical).

# %%
from sklearn.preprocessing import MinMaxScaler

MinMaxtransformer = MinMaxScaler().fit(numericals)
x_normalized = MinMaxtransformer.transform(numericals)
print(x_normalized.shape)
x_normalized = pd.DataFrame(x_normalized,columns=numericals.columns)
x_normalized.head()
# Out:
# (10910, 9)
#    customer lifetime value    income  monthly premium auto  \
# 0                 0.035752  0.480381              0.000000
# 1                 0.004059  0.000000              0.012658
# 2                 0.160264  0.221432              0.164557
# 3                 0.250953  0.490873              0.151899
# 4                 0.087527  0.236795              0.236287
#
#    months since last claim  months since policy inception  \
# 0                 0.200000                       0.525253
# 1                 0.085714                       0.262626
# 2                 0.971429                       0.313131
# 3                 0.285714                       0.030303
# 4                      NaN                       0.313131
#
#    number of open complaints  number of policies  total claim amount  month
# 0                        0.0               1.000            0.101171    1.0
# 1                        0.0               0.000            0.257445    0.0
# ...

# %%
numericals.head() # <-- only so I can compare to x_normalized and try to understand what is happening
# Out:
#    customer lifetime value  income  monthly premium auto  \
# 0              4809.216960   48029                    61
# 1              2228.525238       0                    64
# 2             14947.917300   22139                   100
# 3             22332.439460   49078                    97
# 4              9025.067525   23675                   117
#
#    months since last claim  months since policy inception  \
# 0                      7.0                             52
# 1                      3.0                             26
# 2                     34.0                             31
# 3                     10.0                              3
# 4                      NaN                             31
#
#    number of open complaints  number of policies  total claim amount  month
# 0                        0.0                   9          292.800000      2
# 1                        0.0                   1          744.924331      1
# ...

# %%
#this is how you standardize
from sklearn.preprocessing import StandardScaler

Standardtransformer = StandardScaler().fit(numericals)
x_standardized = Standardtransformer.transform(numericals)
print(x_standardized.shape)
x_standardized = pd.DataFrame(x_standardized,columns=numericals.columns)
x_standardized.head()
# Out:
# (10910, 9)
#    customer lifetime value    income  monthly premium auto  \
# 0                -0.466105  0.345635             -0.934819
# 1                -0.840946 -1.236462             -0.847713
# 2                 1.006523 -0.507194              0.197554
# 3                 2.079112  0.380189              0.110448
# 4                 0.146240 -0.456597              0.691152
#
#    months since last claim  months since policy inception  \
# 0                -0.808451                       0.139877
# 1                -1.205282                      -0.790709
# 2                 1.870158                      -0.611750
# 3                -0.510828                      -1.613919
# 4                      NaN                      -0.611750
#
#    number of open complaints  number of policies  total claim amount     month
# 0                  -0.421143            2.509455           -0.486325  1.068914
# 1                  -0.421143           -0.824922            1.061160 -0.935529
# ...
